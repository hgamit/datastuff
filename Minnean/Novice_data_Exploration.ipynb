# %%
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline


import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
nov_data = pd.read_csv('./Data_Novice/novice_data.csv')

for col_name in list(nov_data):
    col_name_new = col_name.strip()
    col_name_new = re.sub(' +', ' ', col_name_new)
    #col_name_new = re.sub('.', '', col_name_new)
    col_name_new = col_name_new.replace(" ", "_")
    col_name_new = col_name_new.replace("&", "_")
    col_name_new = col_name_new.replace("__", "_")
    nov_data.rename(columns={col_name: col_name_new}, inplace=True)
    
nov_data['Date'] = pd.to_datetime(nov_data['Year'].astype(str)+' '+nov_data['Month'].astype(str))
nov_data.head()
# Out:
#    Month  Year  US_merchandise_exports  US_agricultural_exports  Bulk_export  \
# 0      1  1970                   105.0                     99.1         90.1
# 1      2  1970                   105.3                     99.4         90.3
# 2      3  1970                   105.6                    100.0         90.8
# 3      4  1970                   105.9                    100.4         91.2
# 4      5  1970                   106.2                    100.7         91.4
#
#    Corn_export  Cotton_export  Rice_export  Soybeans_export  Tobacco_export  \
# 0        127.3           78.0         91.7             70.4           101.6
# 1        127.4           78.2         91.9             70.6           102.0
# 2        127.3           78.4         92.1             70.7           103.1
# 3        127.3           79.2         92.2             71.2           103.6
# 4        128.2           78.4         92.0             71.4           103.9
#
# ...

# %%
nov_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 77 columns):
# Month                                           600 non-null int64
# Year                                            600 non-null int64
# US_merchandise_exports                          600 non-null float64
# US_agricultural_exports                         600 non-null float64
# Bulk_export                                     600 non-null float64
# Corn_export                                     600 non-null float64
# Cotton_export                                   600 non-null float64
# Rice_export                                     600 non-null float64
# Soybeans_export                                 600 non-null float64
# Tobacco_export                                  600 non-null float64
# Wheat_export                                    600 non-null float64
# Intermediates_export                            600 non-null float64
# ...

# %%
print(f'{nov_data.shape[0]} samples and {nov_data.shape[1]} features in the training market dataset.')
# Out:
# 600 samples and 77 features in the training market dataset.

# %%
#fig = go.Figure(data=go.Scatter(x=nov_data['Date'] , y=nov_data['U.S._merchandise_exports_to_the_World'] ))

# Create traces
fig = go.Figure()

cols = list(nov_data)
unwanted_col = {"Year", "Month", "Date"} 
wanted = {"US_merchandise_exports", "US_agricultural_exports", "Soybeans_export",  "Soymeal_export", "Soybean__Vegetable_Oil_export",
          "Competitor_merchandise_exports_to_the_World", "Competitor_agricultural_exports_to_the_World", "Soybeans",
          "soymeal", "US_agricultural_import", "Oils_(ex._Soybean)_import", "Agricultural_Related_Products_import"}
  
cols = [ele for ele in cols if ele in wanted] 

'''for col_name in cols:
    fig.add_trace(go.Scatter(x=nov_data['Date'], y=nov_data[col_name],
                    mode='lines',
                    name=col_name))
fig.show()'''

#asset_df = nov_data[(nov_data['Month'] == 5)]
data = []
for col_name in cols[:10]:

    data.append(go.Scatter(x=nov_data['Date'].dt.strftime(date_format='%Y-%m-%d'), y=nov_data[col_name],
                    #mode='lines',
                    name=col_name))
layout = go.Layout(dict(title = "USDA",
                  xaxis = dict(title = ''),
                  yaxis = dict(title = 'Price (USDA)'),
                  ),legend=dict(
                orientation="h"))
py.iplot(dict(data=data, layout=layout), filename='basic-line', image_width=1200,
    image_height=800)
# Out:
# <div>
#
#
#             <div id="28ae8bba-0e54-476c-a699-d2ec24a20b2d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("28ae8bba-0e54-476c-a699-d2ec24a20b2d")) {
#                     Plotly.newPlot(
#                         '28ae8bba-0e54-476c-a699-d2ec24a20b2d',
# ...
